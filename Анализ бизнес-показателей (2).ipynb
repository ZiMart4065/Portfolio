# %% [markdown]
# ## Описание проекта.
# Компания делает огромные вложения в рекламу приложения Procrastinate Pro+. Последние несколько месяцев компания терпит убытки.
# **Цель:**
#
# Разобраться в причинах, помочь компании выйти в плюс.
#
# **Задача.**
#
# Необходимо разобраться:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов,
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ### Описание данных:
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# Структура visits_info_short.csv:
#
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.
#
# Структура orders_info_short.csv:
#
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.
#
# Структура costs_info_short.csv:
#
# - dt — дата проведения рекламной кампании,
# - Channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.

# %% [markdown]
# <h1>Содержание.<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта." data-toc-modified-id="Описание-проекта.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта.</a></span><ul class="toc-item"><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных:</a></span></li></ul></li><li><span><a href="#Загрузка-данных." data-toc-modified-id="Загрузка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка данных.</a></span></li><li><span><a href="#Анализ-данных." data-toc-modified-id="Анализ-данных.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных.</a></span></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии.</a></span></li><li><span><a href="#Исследовательский-анализ-данных." data-toc-modified-id="Исследовательский-анализ-данных.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных.</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей." data-toc-modified-id="Профили-пользователей.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Профили пользователей.</a></span></li><li><span><a href="#Из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей." data-toc-modified-id="Из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.</a></span></li><li><span><a href="#Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи." data-toc-modified-id="Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.</a></span></li><li><span><a href="#Рекламные-источники-привлечения-и--каналы,-из-которых-пришло-больше-всего-платящих-пользователей." data-toc-modified-id="Рекламные-источники-привлечения-и--каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Рекламные источники привлечения и  каналы, из которых пришло больше всего платящих пользователей.</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общую-сумму-расходов-на-маркетинг." data-toc-modified-id="Общую-сумму-расходов-на-маркетинг.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Общую сумму расходов на маркетинг.</a></span></li><li><span><a href="#Траты-на--каждый-источник." data-toc-modified-id="Траты-на--каждый-источник.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Траты на  каждый источник.</a></span></li><li><span><a href="#Изменение-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику." data-toc-modified-id="Изменение-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Изменение расходов во времени (по неделям и месяцам) по каждому источнику.</a></span></li><li><span><a href="#Средняя-стоимость-привлечение-одного-пользователя-(CAC)-для-всего-проекта." data-toc-modified-id="Средняя-стоимость-привлечение-одного-пользователя-(CAC)-для-всего-проекта.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Средняя стоимость привлечение одного пользователя (CAC) для всего проекта.</a></span></li><li><span><a href="#Средняя-стоимость-привлечение-одного-пользователя-(CAC)-из-каждого-источника." data-toc-modified-id="Средняя-стоимость-привлечение-одного-пользователя-(CAC)-из-каждого-источника.-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Средняя стоимость привлечение одного пользователя (CAC) из каждого источника.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li></ul></li><li><span><a href="#Оцените-окупаемость-рекламы" data-toc-modified-id="Оцените-окупаемость-рекламы-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Оцените окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-окупаемости-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графиков-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Анализ-окупаемости-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графиков-динамики-LTV,-CAC-и-ROI.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Анализ окупаемости рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Конверсия-пользователей-и-динамика-её-изменения." data-toc-modified-id="Конверсия-пользователей-и-динамика-её-изменения.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Конверсия пользователей и динамика её изменения.</a></span></li><li><span><a href="#Удержание-пользователей-и-динамика-её-изменения." data-toc-modified-id="Удержание-пользователей-и-динамика-её-изменения.-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Удержание пользователей и динамика её изменения.</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам." data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам.-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам.</a></span><ul class="toc-item"><li><span><a href="#Конверсия-и-удержание-с-разбивкой-по-устройствам." data-toc-modified-id="Конверсия-и-удержание-с-разбивкой-по-устройствам.-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Конверсия и удержание с разбивкой по устройствам.</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам." data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам.-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам.</a></span><ul class="toc-item"><li><span><a href="#Конверсия-и-удержание-с-разбивкой-по-странам." data-toc-modified-id="Конверсия-и-удержание-с-разбивкой-по-странам.-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Конверсия и удержание с разбивкой по странам.</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам." data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам.</a></span><ul class="toc-item"><li><span><a href="#Конверсия-и-удержание-с-разбивкой-по-рекламным-каналам." data-toc-modified-id="Конверсия-и-удержание-с-разбивкой-по-рекламным-каналам.-7.6.1"><span class="toc-item-num">7.6.1&nbsp;&nbsp;</span>Конверсия и удержание с разбивкой по рекламным каналам.</a></span></li></ul></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Выводы.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.8"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Загрузка данных.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime, timedelta
import numpy as np

# %%
# выгружаем данные.
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders_info_short = pd.read_csv('/datasets/orders_info_short.csv')
costs_info_short = pd.read_csv('/datasets/costs_info_short.csv')

print(visits.head(5))
print(orders_info_short.head(5))
print(costs_info_short.head(5))
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# ## Анализ данных.

# %%
# проверим типы данных в каджом датафрейме.
visits.info()
orders_info_short.info()
costs_info_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %%
# приведем столбцы к типу данных согласно их значениям.
# датафрейм visits.
visits['Session Start'] = pd.to_datetime(visits['Session Start'])
visits['Session End'] = pd.to_datetime(visits['Session End'])

# датафрейм orders_info_short.
orders_info_short['Event Dt'] = pd.to_datetime(orders_info_short['Event Dt'])

# датафрейм costs_info_short.
costs_info_short['dt'] = pd.to_datetime(costs_info_short['dt']).dt.date

# %%
# проверим данные на наличие пропусков.
print(visits.isnull().sum())
print(orders_info_short.isnull().sum())
print(costs_info_short.isnull().sum())
# Out:
# User Id          0
# Region           0
# Device           0
# Channel          0
# Session Start    0
# Session End      0
# dtype: int64
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64
# dt         0
# Channel    0
# costs      0
# dtype: int64

# %%
# проверим данные на наличие дубликатов.
print(visits.duplicated().sum())
print(orders_info_short.duplicated().sum())
print(costs_info_short.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# **Выполнена предобработка данных. Пропуски и дубликаты отсутствуют. Столбцы приведены к типу данным согдасно сохраненным в  них значениям.**

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# Зададим функции для вычесления значений метрик:
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %%
# функция для создания пользовательских профилей
def get_profiles(sessions, orders_info_short,costs_info_short):

    # сортируем сессии по ID пользователя и дате посещения
    # группируем по ID и находим первые значения session_start и channel
    # столбец с временем первого посещения назовём first_ts
    # от англ. first timestamp — первая временная отметка
       
    profiles = (
        sessions.sort_values(by=['User Id', 'Session Start'])
        .groupby('User Id')
        .agg({'Session Start': 'first', 
              'Channel': 'first',
             'Region':'first',
             'Device':'first'})
        .rename(columns={'Session Start': 'first_ts'})
        .reset_index()  # возвращаем user_id из индекса
    )

    # определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    # эти данные понадобятся для когортного анализа
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    
    # добавляем признак платящих пользователей
    profiles['payer'] =  profiles['User Id'].isin(orders_info_short['User Id'].unique())
    
# считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'Channel'])
        .agg({'User Id': 'nunique'})
        .rename(columns={'User Id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs_info_short = costs_info_short.merge(new_users, on=['dt', 'Channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs_info_short['acquisition_cost'] = costs_info_short['costs'] / costs_info_short['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs_info_short[['dt', 'Channel', 'acquisition_cost']],
        on=['dt', 'Channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['User Id', 'Session Start']], on='User Id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['Session Start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='User Id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'User Id': 'nunique'})
            .rename(columns={'User Id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['User Id', 'Event Dt'])
        .groupby('User Id')
        .agg({'Event Dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['User Id', 'Event Dt']], on='User Id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['Event Dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='User Id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'User Id': 'nunique'})
            .rename(columns={'User Id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['User Id', 'Event Dt', 'Revenue']], on='User Id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['Event Dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='Revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'User Id': 'nunique'})
            .rename(columns={'User Id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['User Id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных.

# %% [markdown]
# ### Профили пользователей.
# **Определим минимальную и максимальную даты привлечения пользователей.**

# %%
# спользуя функцию get_profiles создадим профили пользователей.
profiles = get_profiles(visits, orders_info_short,costs_info_short)
# определим min  и max даты привлечения пользователей.
min_date = profiles['dt'].min()
max_date = profiles['dt'].max()
print(min_date)
print(max_date)
# Out:
# 2019-05-01
# 2019-10-27

# %% [markdown]
# Самая ранняя дата привлечения пользователей развлекательного приложения Procrastinate Pro+ - **1 мая 2019 года**, самая поздняя дата - **27 октября 2019 года**. Дата совпадает с датой указанной в проекте.

# %% [markdown]
# ### Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.
# **Сравним количество пользователей и долю платящих из каждой страны.**

# %%
# выведем страны из которых пользователи приходят в приложение.
print(profiles['Region'].unique())
# Out:
# ['United States' 'France' 'Germany' 'UK']

# %% [markdown]
# Пользователи приходят из США, Франции, Германии и Великобритании.

# %%
# страна с наибольшим кол-вом платящих пользователей.
payer_pr = profiles.query('payer == True').groupby('Region').agg({'User Id':'nunique'}).sort_values(by = 'User Id', ascending=False).rename(columns={'User Id':'user_payer'})
print(payer_pr)
fig = payer_pr.plot.bar(y='user_payer')
plt.title("Страна с наибольшим кол-вом платящих пользователей")
fig.set_xlabel('Страны')
fig.set_ylabel('Количество платящих пользователей')
plt.show()
# Out:
#                user_payer
# Region
# United States        6902
# UK                    700
# France                663
# Germany               616

# %% [markdown]
# Лидирующую позицию по привлечению платящих пользователей занимает США.

# %%
# кол-во пользователей и доля платящих для каждой страны.
all_profiles = profiles.groupby('Region').agg({'User Id':'count'}).rename(columns={'User Id':'user_count'}).sort_values(by = 'user_count', ascending = False)
payer_profiles = profiles.query('payer == True').groupby('Region').agg({'User Id':'count'}).rename(columns={'User Id':'user_count'})
all_profiles['share'] = (payer_profiles['user_count'] / all_profiles['user_count']).sort_values(ascending = False)
print(all_profiles)
# Out:
#                user_count     share
# Region
# United States      100002  0.069019
# UK                  17575  0.039829
# France              17450  0.037994
# Germany             14981  0.041119

# %% [markdown]
# США занимает первое место по привлечению пользователей. На 100 000 человек приходится 7% платящих. Второе место у Германии, при самых низких показателя привлечения пользоватей у нее высокий процент платящих - 4%. Можно сказать, что качество пользователей у Германии выше,по сравнению с другими странами.

# %% [markdown]
# ### Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.
# **Сравним количество пользователей и долю платящих для каждого устройства.**

# %%
# устройства, которыми пользуются клиенты.
print(profiles['Device'].unique())
# Out:
# ['Mac' 'iPhone' 'PC' 'Android']

# %% [markdown]
# Пользователи заходят в приложение с устройств: 'Mac', 'iPhone', 'PC', 'Android'.

# %%
# устройства, которыми пользуются платящие клиенты.
print(profiles.query('payer == True')['Device'].unique())
# Out:
# ['Mac' 'Android' 'iPhone' 'PC']

# %% [markdown]
# Платящие пользователи заходят с тех же самых устройств: 'Mac','Android', 'iPhone', 'PC'.

# %%
# количество пользователей и долю платящих для каждого устройства.
all_devices = profiles.groupby('Device').agg({'User Id':'count'}).rename(columns={'User Id':'user_count'}).sort_values(by='user_count', ascending = False)

payer_devices  = profiles.query('payer == True').groupby('Device').agg({'User Id':'count'}).rename(columns={'User Id': 'user_count'})

all_devices['share'] = (payer_devices['user_count'] / all_devices['user_count']).sort_values(ascending = False)
print(all_devices)
# Out:
#          user_count     share
# Device
# iPhone        54479  0.062079
# Android       35032  0.058518
# PC            30455  0.050468
# Mac           30042  0.063644

# %% [markdown]
# Пользователи чаще заходят с iPhone, Android  занимает второе место, доля платящих на этих устройства составляет 6%.
# Реже всего приходят с устройств Mac, при этом доля платящих на этих устройствах самая высокая - 6,3%.

# %% [markdown]
# ### Рекламные источники привлечения и  каналы, из которых пришло больше всего платящих пользователей.
# **Сравним количество пользователей и долю платящих для каждого канала привлечения.**

# %%
# кол-во привлеченных пользователей по каналам.
all_channel= profiles.groupby('Channel').agg({'User Id':'nunique'}).sort_values(by = 'User Id', ascending=False).rename(columns={'User Id': 'user_count'})
fig = all_channel.plot.bar(y='user_count')
plt.title("Кол-во привлеченных пользователей по каналам")
fig.set_xlabel('Каналы')
fig.set_ylabel('Количество привлеченных пользователей')
plt.show()

# %% [markdown]
# Тройка лидеров среди каналов по привлечению занимает organic, FaceBoom, TipTop. Бесспорный лидер канал "organic", он привлек 56500 пользователей.

# %%
# кол-во платящих пользователй по каждому каналу.
payer_channel = profiles.query('payer == True').groupby('Channel').agg({'User Id':'nunique'}).sort_values(by = 'User Id', ascending=False).rename(columns={'User Id': 'user_payer'})

fig = payer_channel.plot.bar(y='user_payer')
plt.title("Кол-во платящих пользователй по каждому каналу")
fig.set_xlabel('Каналы')
fig.set_ylabel('Количество платящих пользователей')
plt.show()

# %% [markdown]
# Канал "FaceBoom" лидирует по привлечению платящих пользователей. На втором месте "TipTop". 3 место у канала "organic" - лидера по привлечению общего кол-ва пользователей.

# %%
#количество пользователей и доля платящих для каждого канала привлечения.
payer_channel = profiles.query('payer == True').groupby('Channel').agg({'User Id':'count'}).rename(columns={'User Id': 'user_count'})
all_channel['share'] = payer_channel['user_count'] / all_channel['user_count']
all_channel = all_channel.sort_values(by='share', ascending=False)
all_channel
# Out:
#                     user_count     share
# Channel
# FaceBoom                 29144  0.122049
# AdNonSense                3880  0.113402
# lambdaMediaAds            2149  0.104700
# TipTop                   19561  0.096007
# RocketSuperAds            4448  0.079137
# WahooNetBanner            8553  0.052964
# YRabbit                   4312  0.038265
# MediaTornado              4364  0.035747
# LeapBob                   8553  0.030633
# OppleCreativeMedia        8605  0.027077
# organic                  56439  0.020553

# %% [markdown]
# При рассмотрении доли платящих для каждого канала в долях, видим, что "FaceBoom" занимает первое место. На второе и третье выходят каналы "AdNonSense" и "lambdaMediaAds" при небольшом кол-ве общих пользователей, доля платящих достаточно высокая.
#
# Канал "organic" привлек наибольшее кол-во пользователей, но процент платящих из них самый низкий.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Общую сумму расходов на маркетинг.

# %%
# расчитаем общую сумму расходов на маркетинг.
total_amount = costs_info_short['costs'].sum()
total_amount
# Out:
# 105497.30000000002

# %% [markdown]
# Общая сумма расходов на маркетинг составляет 105497`$`

# %% [markdown]
# ### Траты на  каждый источник.

# %%
# расходы на каждый источник.
costs_channel = costs_info_short.groupby('Channel').sum().sort_values(by='costs', ascending=False)
print(costs_channel)
fig = costs_channel.plot.bar(y='costs')
plt.title("Расходы на каждый источник")
fig.set_xlabel('Источники')
fig.set_ylabel('Расходы')
plt.show()
# Out:
#                        costs
# Channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %%
# посмотрим расходы на каждый источник от общей суммы в %.
costs_percent = costs_channel / costs_info_short['costs'].sum()*100
print(costs_percent)
fig = costs_percent.plot.bar(y='costs')
plt.title('Расходы на каждый источник от общей суммы в %')
fig.set_xlabel('Источники')
fig.set_ylabel('Расходы,%')
plt.show()
# Out:
#                         costs
# Channel
# TipTop              51.898295
# FaceBoom            30.754910
# WahooNetBanner       4.882589
# AdNonSense           3.707441
# OppleCreativeMedia   2.039152
# RocketSuperAds       1.737485
# LeapBob              1.703930
# lambdaMediaAds       1.476436
# MediaTornado         0.904744
# YRabbit              0.895018

# %% [markdown]
# На платформу "TipTop" было потрачено  51% от общей суммы бюджета. Второе место по денежным вливаниям занимает "FaceBoom" - 31%. Оставшиеся 17 %  распределены между остальными платформами с незначительными колебаниями.

# %% [markdown]
# ### Изменение расходов во времени (по неделям и месяцам) по каждому источнику.

# %%
# динамика изменения расходов во времени (по неделям и месяцам) по каждому источнику.
# создадим столбцы month и week.
costs_info_short['month'] = costs_info_short['dt'].astype('datetime64[M]') 
costs_info_short['week'] = costs_info_short['dt'].astype('datetime64[W]')
# динамика изменения расходов во времени по месяцам по каждому источнику.
costs_info_short.pivot_table(
    index=['month'],  # даты первых посещений
    columns='Channel',  # источники переходов
    values='costs',  # ID пользователей
    aggfunc='sum'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)
# динамика изменения расходов во времени по неделям по каждому источнику.
costs_info_short.pivot_table(
    index=['week'],  # даты первых посещений
    columns='Channel',  # источники переходов
    values='costs',  # ID пользователей
    aggfunc='sum'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)
plt.show()

# %% [markdown]
# Динамика расходов по месяцам показывает, что начиная с мая, компания увеличивает вложения в платформу "TipTop", сумма вложений ежемесячно растет. Пик наблюдаем в сентябре, в этом месяце сумма вливаний достигла 13800 `$`. В октябре наблюдаем незначительное снижение инвестиций. Увеличились вложения в маркетинг и на Платформа "FaceBoom", расходы  с мая по июнь выросли на 2000`$`. В следующие месяцы расходы не привышали 1000 `$`.
# Динамика расходов по неделям показывает - расходы на каналы "TipTop" и "FaceBoom" увеличивались в последнюю неделю каждого месяца.

# %% [markdown]
# ### Средняя стоимость привлечение одного пользователя (CAC) для всего проекта.

# %%
# уберем пользователей "organic".
profiles = profiles.query('Channel != "organic"')
# посчитаем общее кол-во привлеченных пользователей.
count_profiles = profiles['User Id'].count()
# средний CAC на одного привлеченного пользователя.
mean_costs_one_person = total_amount / count_profiles
mean_costs_one_person
# Out:
# 1.127481323942759

# %% [markdown]
# Средняя стоимость одного привлеченного пользователя равна 1.13 `$`

# %% [markdown]
# ### Средняя стоимость привлечение одного пользователя (CAC) из каждого источника.

# %%
# уберем пользователей "organic".
all_channel = all_channel.query('Channel != "organic"')
# средняя стоимость привлечения одного пользователя.
mean_costs = costs_channel['costs'] / all_channel['user_count']
mean_costs = mean_costs.fillna(0).sort_values(ascending=False)
print(mean_costs)
fig = mean_costs.plot.bar(y='Channel')
plt.title('Cредняя стоимость привлечения одного пользователя')
fig.set_xlabel('Каналы')
fig.set_ylabel('Средняя стоимость')
plt.show()
# Out:
# Channel
# TipTop                2.799003
# FaceBoom              1.113286
# AdNonSense            1.008054
# lambdaMediaAds        0.724802
# WahooNetBanner        0.602245
# RocketSuperAds        0.412095
# OppleCreativeMedia    0.250000
# YRabbit               0.218975
# MediaTornado          0.218717
# LeapBob               0.210172
# dtype: float64

# %% [markdown]
# Самы "дорогой" пользователь у канала "TipTop", стоимость привлечения 1-го человека обошлось компании в 3 `$`.
# Платформе "FaceBoom" пользователь обошелся в 1`$`.

# %% [markdown]
# #### Вывод:
# Самыми дорогими каналами для компании стали "TipTop" и "FaceBoom", на них было потрачено 82% от общего бюджета. Средняя стоимость привлечения одного пользователя для канала "TipTop" составляет 3$, для "FaceBoom" - чуть больше 1`$`, при средней стоимости привлеченного пользователя в 1,13`$`. Эти каналы привлекают больше всего пользователей.Но при рассмотрении доли платящих для каждого канала, видим, что "FaceBoom" занимает первое место. На второе и третье выходят каналы "AdNonSense" и "lambdaMediaAds" при небольшом кол-ве общих пользователей, доля платящих достаточно высокая.

# %% [markdown]
# ## Оцените окупаемость рекламы
#
# **Используя графики LTV, ROI и CAC, проанализируем окупаемость рекламы. Учтем, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.**

# %% [markdown]
# ### Анализ окупаемости рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.

# %%
# задаем момент и горизонт анализа.
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %%
# рассчитываем LTV и ROI
# уберем из расчетов пользователей "organic"
profiles = profiles.query('Channel != "organic"')
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles, orders_info_short,  observation_date, horizon_days)

# %%
# строим графики LTV и ROI, динамики LTV, CAC и ROI.
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %% [markdown]
# Графика показывают:
# 1. Реклама не окупается, средние показатели ROI чуть выше 80% при среднем LTV в 95%.
# 2. Динамика LTV относительно стабильная, но с перепадами. CAC растет, траты на маркетинг увеличиваются, ROI падает - вложения не окупаются.

# %% [markdown]
#  ### Конверсия пользователей и динамика её изменения.

# %%
# смотрим конверсию и динамику ее изменения.

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders_info_short, observation_date, horizon_days)


plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия пользователей растет.

# %% [markdown]
#  ### Удержание пользователей и динамика её изменения.

# %%
#  удержанием  платящих и неплатящих пользователей, динамика изменений.
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days)


plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей падает. Неплатящие не удерживаются совсем.

# %% [markdown]
# **Реклама не окупается, пользователи конвертируются, но не удерживаются.**

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам.
# **Графики LTV и ROI, а также графики динамики LTV, CAC и ROI.**

# %%
# окупаемость рекламы с разбивкой по устройствам.

dimensions = ['Device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders_info_short, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Окупаемость рекламы с разбивкой по устройствам:
# 1. Наблюдаем рост LTV на всех устройствах, но превышает порог окупаемости только  PC. PC с трудом превышает отметку в 100%.
# 2. Динамика LTV пользователей относительно стабильная.
# 3. Стоимость привлечения пользователей стабильно растет, самые высокие показатели у iPhone и Mac, но им не удается приблизиться к горизонту окупаемости. Реклама окупается только на устройстве PC, но начиная с сентября перестает окупаться.

# %% [markdown]
# #### Конверсия и удержание с разбивкой по устройствам.

# %%
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders_info_short, observation_date, horizon_days, dimensions = ['Device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
#  Все каналы показывают стабильную конверсию. Канал PC стабилен, но показатели значительно ниже.

# %%
# удержанием  платящих и неплатящих пользователей по устройствам, динамика изменений.
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days,dimensions = ['Device'])


plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Все каналы теряют своих посетителей, удержание платящих стабильно падает. Немного выше удержание у канала PC, но в динамике видим, что с сентября  по потерям он догоняет другие дeвайсы.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам.
# **Графики LTV и ROI, а также графики динамики LTV, CAC и ROI.**

# %%
#окупаемость рекламы с разбивкой по странам.
dimensions = ['Region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders_info_short, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Окупаемость рекламы с разбивкой по странам:
# 1. Франция, Германия и Великобритания демонстрируют высокие средние показатели ROI. ROI в США едва достигает 90%.
# 2. США демонстрирует лучшие показатели LTV, при этом стоимость привлечения пользователей достаточно высокая, окупаемости нет.
# 3. Другие страны демонстрируют окупаемость рекламы при минимальных вложениях.
#
# Рассмотрим конверсию и удержание по странам.

# %% [markdown]
# #### Конверсия и удержание с разбивкой по странам.

# %%
#конверсия с разбивкой по странам.
dimensions = ['Region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders_info_short, observation_date, horizon_days, dimensions = dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# США демонстрирует значительный отрыв по конверсии пользователей.

# %%
# удержанием  платящих и неплатящих пользователей по странам, динамика изменений.
dimensions = ['Region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days,dimensions =dimensions)


plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# А вот удержать пользователей у США не получается. Показатели значительно хуже по сравнению с другими странами.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам.
# **Графики LTV и ROI, а также графики динамики LTV, CAC и ROI.**

# %%
#окупаемость рекламы с разбивкой по рекламным каналам.
dimensions = ['Channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders_info_short, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Не окупаются каналы "Tip-Top","FaseBoom","AdNonSense".

# %% [markdown]
# #### Конверсия и удержание с разбивкой по рекламным каналам.

# %%
#конверсия с разбивкой по каналам.
dimensions = ['Channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders_info_short, observation_date, horizon_days, dimensions = dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Рост конверсии у 6 каналов. Лучшие результаты у "FaseBoom", "AdNonSense", "lambdaMediaAds" и "Tip-Top".

# %%
# удержанием  платящих и неплатящих пользователей по странам, динамика изменений.
dimensions = ['Channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days,dimensions =dimensions)


plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# При лучшей конверсии, удержание пользователей у каналов "FaseBoom" и "AdNonSense" стремиться к нулю. Удержание неплатящих одинаково стретимиться к нулю по всем каналам.

# %% [markdown]
# ### Выводы.
# **Окупаемость рекламы, направленной на привлечение пользователей в целом.**
#  - Высокие траты на рекламу с одной стороны позволяют привлечь большее кол-во пользователей, с другой стороны "стоимость" одного пользователя значительно возрастает. Реклама не окупается.
#
# **Устройства, страны и рекламные каналы, которые оказывают негативное влияние на окупаемость рекламы.**
# - США привлекает и конвертирует огромное, по сравнению с другими странами, кол-во пользоватей. Но показатели удержания значительно ниже, по сравнению с другими странами. При этом на маркетинг США тратиться 51% от общего бюджета.
# - Мы рассматриваем окупаемость рекламы по устройствам: 'Mac' 'iPhone' 'PC' 'Android'. Ни одно устройство не окупается.
# - Не окупаются каналы "Tip-Top","FaseBoom","AdNonSense". У всех 3-х каналов хорошие показатели конверсии. Однако каналы "FaseBoom" и "AdNonSense" не удерживают пользователей. Канал "Tip-Top" при хорошей конверсии и удержании, стоит слишком дорого.
#
# **Чем могут быть вызваны проблемы окупаемости?**
# - Высокой стоимостью популярных каналов.
# - Низкой конверсией.
# - Низким качеством посетителй.

# %% [markdown]
# ### Вывод
#
# - Причины неэффективности привлечения пользователей.
# - Рекомендации для отдела маркетинга.

# %% [markdown]
# **Причины неокупаемости по странам:**
#
# Из всех стран США лидирует по кол-ву привлеченных пользователей, показывает хорошие результаты конверсии. Стоимость привлечения самая высокая, а удержание пользователей самое низкое. Поэтому реклама не окупается.
# Рекомендуем перенаправить часть рекламного бюджета на другие страны, т.к. доля платящих пользователей по отношению к общему числу привлеченных достаточно высокая. Перенаправление средств из рекламного бюджета поможет усилить конверсию и удержание.
#
# **Причины неокупаемости по каналам:**
# 82% рекламного бюждета тратится на популярные каналы "TipTop","FaseBoom".
#
# Средняя стоимость одного привлеченного пользователя по каналу **"TipTop"** равна 3`$`, при средней стоимости привлеченного пользователя по проекту в целом 1,13`$`. Как мы видим по графикам стоимость пользователя постоянно растет. И хотя канал показывает стабильную конверсию и удержание пользователей, слишком дорогая реклама не позволяет вложениям окупиться.
#
# Средняя стоимость одного привлеченного пользователя по каналу **"FaceBoom"** чуть выше 1`$`. Канал демонстрирует хорошую конверсию, но удержание стремится к нулю. Соответственно реклама не окупается.
#
# Средняя стоимость одного привлеченного пользователя по каналу **"AdNonSense"** равна 1`$`. Канал также демонстрирует стабильную конверсию, но удержание стремиться к нулю. Реклама не окупается.
# Стоит рассмотреть каналы с меньшей стоимостью привлечения пользователя, хорошей конверсией и удержанием. Например, каналы **"lambdaMediaAds", "RocketSuperAds", "YRabbit","WahooNetBanner"**. Стоимость одного пользователя по этим каналам не привышает среднюю стоимость пользователя по проекту или же значительно ниже. Удержание хорошее, реклама окупается. Привлечение и конверсию можно улучшить перенаправив бюджет рекламы на эти каналы.
#
# **Причины неокупаемости по устройствам:**
# Устройства 'Mac','Android', 'iPhone', 'PC' демонстрирую примерно одинаковую популярность среди потребителей. Конверсия пользователей и удержание примерно одинаковые. Но 'Mac' и 'Android' обходятся компании значительно дороже. Ниже всего цена на PC, его конверсия ниже других платформ, а удержание такое же. Это перспективная платформа, которая может окупиться. На данный момент ни одна из платформ не окупается.
